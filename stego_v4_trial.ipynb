# %% [markdown]
# # Import Library

# %%
from collections import OrderedDict
import pickle

from pee_stego_v4 import PEEStego

# %% [markdown]
# # Set up the secret

# %%
from utils.data_preparation import get_filenames_from_folder, get_secret_file

# Tentukan folder path tempat secret
SECRET_FOLDER_PATH = 'keys/bin'

# Dapatkan semua nama file .txt dari folder
secret_filenames = get_filenames_from_folder('txt', SECRET_FOLDER_PATH)
secret_filenames.sort(reverse=True)
print(secret_filenames)

# Masukkan ke dalam dictionary berisi nama filename beserta isi secret filenya
secret_dicts = OrderedDict((secret_filename, get_secret_file(
    SECRET_FOLDER_PATH + '/' + secret_filename + '.txt')) for secret_filename in secret_filenames)
# print(secret_dicts.get(secret_filenames[1]))

for secret_name, secret_data in secret_dicts.items():
    print(f"Secret untuk {secret_name}")
# Out:
# ['secret_0.99_bps', 'secret_0.66_bps', 'secret_0.51_bps', 'secret_0.48_bps', 'secret_0.39_bps', 'secret_0.32_bps', 'secret_0.21_bps', 'secret_0.15_bps', 'secret_0.08_bps']
# Secret untuk secret_0.99_bps
# Secret untuk secret_0.66_bps
# Secret untuk secret_0.51_bps
# Secret untuk secret_0.48_bps
# Secret untuk secret_0.39_bps
# Secret untuk secret_0.32_bps
# Secret untuk secret_0.21_bps
# Secret untuk secret_0.15_bps
# Secret untuk secret_0.08_bps

# %% [markdown]
# # Pick sample patient

# %%
from utils.data_preparation import get_original_data

patient_code = '100'
original_data = get_original_data(patient_code=patient_code)

# %% [markdown]
# # Run model trial

# %%
stego = PEEStego()
payload_rate = 2
threshold = 0


for secret_name, secret_data in secret_dicts.items():
    print(f"Secret untuk {secret_name}")
    print(
        f"Secret {secret_name} payload_rate {payload_rate} threshold {threshold}")
    print(">>Embedding...")
    watermarked_data, mirror_data, last_phase, last_i, last_embedded_bit_total, result = stego.embed(
        original_data, secret_data, payload_rate=payload_rate, threshold=threshold)
    print(
        f"Last Phase: {last_phase}, Last I: {last_i}, Last embedded bit: {last_embedded_bit_total}")
    
    print(">>Extracting...")
    extracted_original_data, extracted_secret_data = stego.extract(
        watermarked_data, mirror_data, last_phase, last_i, last_embedded_bit_total, payload_rate=payload_rate, threshold=threshold)

    print(">>", original_data[0:20], secret_data[0:20])
    print(">>", extracted_original_data[0:20],
          extracted_secret_data[0:20])
    print(">>", "Len -> Ori:", len(original_data), ", Ex-ori:", len(extracted_original_data),
            ", Sec:", len(
                secret_data), ", Ex-sec:", len(extracted_secret_data))
    print("******\n******")
# Out:
# Secret untuk secret_0.99_bps
# Secret secret_0.99_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -146 -145 -120 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 336
# Unhidden secret: 0
# NCC: 0.9999874782860781
# PRD: 0.23563393645947725
# SNR: 52.55524322882711
# PSNR: 30.508578295522245
# Time: 0.08400654792785645
# Last Phase: 2, Last I: 3181, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11101111011001110011
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11101111011001110011
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 3564 , Ex-sec: 3564
# ******
# ******
# Secret untuk secret_0.66_bps
# Secret secret_0.66_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -144 -145 -119 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 217
# Unhidden secret: 0
# NCC: 0.9999918119588211
# PRD: 0.19018280122478165
# SNR: 54.416575202325326
# PSNR: 31.44376582856112
# Time: 0.045005083084106445
# Last Phase: 2, Last I: 826, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -119 -135]
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 10001100010100101011
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 10001100010100101011
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 2376 , Ex-sec: 2376
# ******
# ******
# Secret untuk secret_0.51_bps
# Secret secret_0.51_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 160
# Unhidden secret: 0
# NCC: 0.999993812905322
# PRD: 0.16531202335636982
# SNR: 55.633911169656216
# PSNR: 32.047912265936795
# Time: 0.03099822998046875
# Last Phase: 1, Last I: 3363, Last embedded bit: 2
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11011010101001000111
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11011010101001000111
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 1836 , Ex-sec: 1836
# ******
# ******
# Secret untuk secret_0.48_bps
# Secret secret_0.48_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -118 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 145
# Unhidden secret: 0
# NCC: 0.999993836109781
# PRD: 0.16505592401846164
# SNR: 55.647377676008944
# PSNR: 32.05464551911315
# Time: 0.03000473976135254
# Last Phase: 1, Last I: 3150, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 01011010000111001110
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 01011010000111001110
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 1728 , Ex-sec: 1728
# ******
# ******
# Secret untuk secret_0.39_bps
# Secret secret_0.39_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 113
# Unhidden secret: 0
# NCC: 0.99999519405249
# PRD: 0.14572700559534107
# SNR: 56.72919917815686
# PSNR: 32.59555627018712
# Time: 0.022000551223754883
# Last Phase: 1, Last I: 2535, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11001001011110000011
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11001001011110000011
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 1404 , Ex-sec: 1404
# ******
# ******
# Secret untuk secret_0.32_bps
# Secret secret_0.32_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -119 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 90
# Unhidden secret: 0
# NCC: 0.9999958675924763
# PRD: 0.13518548264949592
# SNR: 57.38139888145794
# PSNR: 32.92165612183765
# Time: 0.0180051326751709
# Last Phase: 1, Last I: 2070, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 10011001111000001100
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 10011001111000001100
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 1152 , Ex-sec: 1152
# ******
# ******
# Secret untuk secret_0.21_bps
# Secret secret_0.21_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 45
# Unhidden secret: 0
# NCC: 0.999997216059588
# PRD: 0.11085652248975139
# SNR: 59.104774982343564
# PSNR: 33.783344172280465
# Time: 0.011998414993286133
# Last Phase: 1, Last I: 1305, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11100110010110100001
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11100110010110100001
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 756 , Ex-sec: 756
# ******
# ******
# Secret untuk secret_0.15_bps
# Secret secret_0.15_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -118 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 31
# Unhidden secret: 0
# NCC: 0.9999979087025431
# PRD: 0.09614216621922225
# SNR: 60.34172193654265
# PSNR: 34.401817649380014
# Time: 0.01000213623046875
# Last Phase: 1, Last I: 921, Last embedded bit: 2
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 01100110110100101000
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 01100110110100101000
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 540 , Ex-sec: 540
# ******
# ******
# Secret untuk secret_0.08_bps
# Secret secret_0.08_bps payload_rate 2 threshold 0
# >>Embedding...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# Total yang kurang dari sama dengan threshold (T = 1): 22
# Unhidden secret: 0
# NCC: 0.9999989512602314
# PRD: 0.06806051674235128
# SNR: 63.342095157845684
# PSNR: 35.90200426003153
# Time: 0.005000114440917969
# Last Phase: 1, Last I: 510, Last embedded bit: 1
# >>Extracting...
# [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135]
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11010110001001001100
# >> [-145 -145 -145 -145 -145 -145 -145 -145 -120 -135 -145 -150 -160 -155
#  -160 -175 -180 -185 -170 -155] 11010110001001001100
# >> Len -> Ori: 3600 , Ex-ori: 3600 , Sec: 288 , Ex-sec: 288
# ******
# ******
